# %%
from PIL import Image
import PIL

# %%
img = Image.open('thumb.jpeg')
img.show()

# %%
img.size
# Out:
# (1500, 500)

# %%
img.format
# Out:
# 'JPEG'

# %%
img.mode
# Out:
# 'RGB'

# %%
img.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x500>

# %%
img.rotate(90, expand=1)
# Out:
# <PIL.Image.Image image mode=RGB size=500x1500>

# %%
img.transpose(method=Image.FLIP_TOP_BOTTOM)
# Out:
# /var/folders/h7/lgzx36497bv35t__0ld2n1m80000gn/T/ipykernel_15917/2887921028.py:1: DeprecationWarning: FLIP_TOP_BOTTOM is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.FLIP_TOP_BOTTOM instead.
#   img.transpose(method=Image.FLIP_TOP_BOTTOM)
# <PIL.Image.Image image mode=RGB size=1500x500>

# %%
img.resize((100, 100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
width, height = img.size
print(width, height)
# Out:
# 1500 500

# %%
new_width = int(width/3)
new_height = int(height/3)

# %%
small_image = img.resize((new_width, new_height))
small_image
# Out:
# <PIL.Image.Image image mode=RGB size=500x166>

# %%
small_image.size
# Out:
# (500, 166)

# %%
small_image.save('small_thumb.jpeg')

# %%
MAX_SIZE = (300, 300)
img2 = img.copy()
img2.thumbnail(MAX_SIZE)
img2
# Out:
# <PIL.Image.Image image mode=RGB size=300x100>

# %%
img2.size
# Out:
# (300, 100)

# %%
## bir fotograf klasorunde okuma ve kirpma islemi ornegi yapalim

# %%
import os

# %%
folder_path = './images'
paths = os.listdir(folder_path)
for path in paths:
    if path.endswith(".jpg") :
        img = Image.open(os.path.join(folder_path, path))
        thumb = img.copy()
        thumb.thumbnail((300, 300))
        thumb = thumb.transpose(Image.FLIP_LEFT_RIGHT)
        thumb.save(f'./processed_images/{path}')
# Out:
# /var/folders/h7/lgzx36497bv35t__0ld2n1m80000gn/T/ipykernel_15917/3862002301.py:8: DeprecationWarning: FLIP_LEFT_RIGHT is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.FLIP_LEFT_RIGHT instead.
#   thumb = thumb.transpose(Image.FLIP_LEFT_RIGHT)
