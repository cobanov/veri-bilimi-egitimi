# %%
import pandas as pd

# %%
dataframe = pd.read_csv('./titanic.csv')

# %%
dataframe.head()
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %%
dataframe.tail()
# Out:
#                         Name PClass   Age   Sex  Survived  SexCode
# 1308      Zakarian, Mr Artun    3rd  27.0  male         0        0
# 1309  Zakarian, Mr Maprieder    3rd  26.0  male         0        0
# 1310        Zenni, Mr Philip    3rd  22.0  male         0        0
# 1311        Lievens, Mr Rene    3rd  24.0  male         0        0
# 1312          Zimmerman, Leo    3rd  29.0  male         0        0

# %%
dataframe.shape
# Out:
# (1313, 6)

# %%
dataframe.iloc[0]
# Out:
# Name        Allen, Miss Elisabeth Walton
# PClass                               1st
# Age                                 29.0
# Sex                               female
# Survived                               1
# SexCode                                1
# Name: 0, dtype: object

# %%
dataframe.iloc[:5]
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %%
dataframe.iloc[-5:]
# Out:
#                         Name PClass   Age   Sex  Survived  SexCode
# 1308      Zakarian, Mr Artun    3rd  27.0  male         0        0
# 1309  Zakarian, Mr Maprieder    3rd  26.0  male         0        0
# 1310        Zenni, Mr Philip    3rd  22.0  male         0        0
# 1311        Lievens, Mr Rene    3rd  24.0  male         0        0
# 1312          Zimmerman, Leo    3rd  29.0  male         0        0

# %%
dataframe[dataframe['Sex'] == 'female']
# Out:
#                                                Name PClass   Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                       Allison, Miss Helen Loraine    1st   2.0  female
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
# 6                  Andrews, Miss Kornelia Theodosia    1st  63.0  female
# 8      Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.0  female
# ...                                             ...    ...   ...     ...
# 1283            Vestrom, Miss Hulda Amanda Adolfina    3rd  14.0  female
# 1293                              Wilkes, Mrs Ellen    3rd  45.0  female
# 1304                            Yasbeck, Mrs Antoni    3rd  15.0  female
# 1306                            Zabour, Miss Hileni    3rd   NaN  female
# 1307                            Zabour, Miss Tamini    3rd   NaN  female
#
#       Survived  SexCode
# 0            1        1
# 1            0        1
# ...

# %%
dataframe[dataframe['Sex'] == 'female'].head()
# Out:
#                                             Name PClass   Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
# 6               Andrews, Miss Kornelia Theodosia    1st  63.0  female
# 8   Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.0  female
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 3         0        1
# 6         1        1
# 8         1        1

# %%
dataframe['Sex'].replace('female', 'F')
# Out:
# 0          F
# 1          F
# 2       male
# 3          F
# 4       male
#         ...
# 1308    male
# 1309    male
# 1310    male
# 1311    male
# 1312    male
# Name: Sex, Length: 1313, dtype: object

# %%
dataframe['Sex'].replace(['female', 'male'],['F', 'M'])
# Out:
# 0       F
# 1       F
# 2       M
# 3       F
# 4       M
#        ..
# 1308    M
# 1309    M
# 1310    M
# 1311    M
# 1312    M
# Name: Sex, Length: 1313, dtype: object

# %%
dataframe
# Out:
#                                                Name PClass    Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                       Allison, Miss Helen Loraine    1st   2.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                     Allison, Master Hudson Trevor    1st   0.92    male
# ...                                             ...    ...    ...     ...
# 1308                             Zakarian, Mr Artun    3rd  27.00    male
# 1309                         Zakarian, Mr Maprieder    3rd  26.00    male
# 1310                               Zenni, Mr Philip    3rd  22.00    male
# 1311                               Lievens, Mr Rene    3rd  24.00    male
# 1312                                 Zimmerman, Leo    3rd  29.00    male
#
#       Survived  SexCode
# 0            1        1
# 1            0        1
# ...

# %%
dataframe['Sex'] = dataframe['Sex'].replace(['female', 'male'],['F', 'M'])

# %%
dataframe.head()
# Out:
#                                             Name PClass    Age Sex  Survived  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00   F         1
# 1                    Allison, Miss Helen Loraine    1st   2.00   F         0
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00   M         0
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00   F         0
# 4                  Allison, Master Hudson Trevor    1st   0.92   M         1
#
#    SexCode
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0

# %%
dataframe.rename(columns={'PClass':'PassengerClass', 'Sex':'Gender'})
# Out:
#                                                Name PassengerClass    Age  \
# 0                      Allen, Miss Elisabeth Walton            1st  29.00
# 1                       Allison, Miss Helen Loraine            1st   2.00
# 2               Allison, Mr Hudson Joshua Creighton            1st  30.00
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)            1st  25.00
# 4                     Allison, Master Hudson Trevor            1st   0.92
# ...                                             ...            ...    ...
# 1308                             Zakarian, Mr Artun            3rd  27.00
# 1309                         Zakarian, Mr Maprieder            3rd  26.00
# 1310                               Zenni, Mr Philip            3rd  22.00
# 1311                               Lievens, Mr Rene            3rd  24.00
# 1312                                 Zimmerman, Leo            3rd  29.00
#
#      Gender  Survived  SexCode
# 0         F         1        1
# ...

# %%
dataframe['Age'].min()
# Out:
# 0.17

# %%
dataframe['Age'].max()
# Out:
# 71.0

# %%
dataframe['Age'].mean()
# Out:
# 30.397989417989418

# %%
dataframe['Age'].sum()
# Out:
# 22980.88

# %%
dataframe['Age'].count()
# Out:
# 756

# %%
dataframe['Sex'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
dataframe['Sex'].value_counts()
# Out:
# M    851
# F    462
# Name: Sex, dtype: int64

# %%
dataframe['PClass'].value_counts()
# Out:
# 3rd    711
# 1st    322
# 2nd    279
# *        1
# Name: PClass, dtype: int64

# %%
dataframe.isnull()
# Out:
#        Name  PClass    Age    Sex  Survived  SexCode
# 0     False   False  False  False     False    False
# 1     False   False  False  False     False    False
# 2     False   False  False  False     False    False
# 3     False   False  False  False     False    False
# 4     False   False  False  False     False    False
# ...     ...     ...    ...    ...       ...      ...
# 1308  False   False  False  False     False    False
# 1309  False   False  False  False     False    False
# 1310  False   False  False  False     False    False
# 1311  False   False  False  False     False    False
# 1312  False   False  False  False     False    False
#
# [1313 rows x 6 columns]

# %%
dataframe.isnull().sum()
# Out:
# Name          0
# PClass        0
# Age         557
# Sex           0
# Survived      0
# SexCode       0
# dtype: int64

# %%
## bir sonraki ders eksik verilerin nasil tamamlanacagini gostermek ile baslar
