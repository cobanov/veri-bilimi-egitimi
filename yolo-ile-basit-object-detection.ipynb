# %%
## https://pytorch.org/hub/ultralytics_yolov5/

# %%
import torch

# Model Settings
model = torch.hub.load("ultralytics/yolov5", "yolov5s", pretrained=True)
# Out:
# Using cache found in /Users/cobanov/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-6-7 Python-3.8.13 torch-1.11.0 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
image_path = './processed_images/ec1m_00090018.jpg'

results = model(image_path)
results.show()

# %%
results.print()
# Out:
# image 1/1: 225x300 3 persons
# Speed: 3.2ms pre-process, 100.8ms inference, 0.6ms NMS per image at shape (1, 3, 480, 640)

# %%
results.pandas().xyxy[0]
# Out:
#          xmin        ymin        xmax        ymax  confidence  class    name
# 0  105.239769  100.663696  155.721832  196.831116    0.781212      0  person
# 1   34.948139   64.812126   90.603844  163.036591    0.759338      0  person
# 2   79.271706   52.336384   96.028099   91.075333    0.545652      0  person

# %%
import os

# %%
images = os.listdir('./images/')
print(images[:5])
# Out:
# ['ec1m_00090020.jpg', 'ec1m_00100023.jpg', 'ec1m_00100022.jpg', 'ec1m_00100008.jpg', 'ec1m_00100020.jpg']

# %%
images_full = [os.path.join('./images', i) for i in images]
images_full[:5]
# Out:
# ['./images/ec1m_00090020.jpg',
#  './images/ec1m_00100023.jpg',
#  './images/ec1m_00100022.jpg',
#  './images/ec1m_00100008.jpg',
#  './images/ec1m_00100020.jpg']

# %%
results = model(images_full)

# %%
results.print()
# Out:
# image 1/30: 334x500 1 person
# image 2/30: 333x500 20 persons
# image 3/30: 375x500 7 persons, 1 giraffe, 2 backpacks, 1 handbag
# image 4/30: 375x500 18 persons, 2 handbags
# image 5/30: 375x500 17 persons, 1 backpack
# image 6/30: 333x500 15 persons, 1 handbag
# image 7/30: 330x500 10 persons, 2 handbags
# image 8/30: 375x500 19 persons, 1 clock
# image 9/30: 500x333 11 persons, 1 backpack, 1 handbag, 1 cell phone
# image 10/30: 375x500 16 persons, 1 handbag
# image 11/30: 333x500 13 persons, 2 backpacks, 5 handbags
# image 12/30: 375x500 5 persons, 2 backpacks
# image 13/30: 500x338 11 persons, 1 handbag
# image 14/30: 375x500 4 persons
# image 15/30: 375x500 18 persons, 1 backpack, 4 handbags
# image 16/30: 375x500 13 persons, 1 backpack, 1 handbag
# image 17/30: 333x500 1 person
# image 18/30: 334x500 11 persons, 4 handbags
# image 19/30: 333x500 17 persons, 3 handbags
# image 20/30: 375x500 18 persons, 1 bicycle, 1 handbag
# image 21/30: 500x332 9 persons
# image 22/30: 375x500 10 persons
# image 23/30: 335x500 16 persons
# image 24/30: 375x500 7 persons
# image 25/30: 333x500 12 persons
# image 26/30: 375x500 19 persons, 2 backpacks, 1 clock
# image 27/30: 375x500 11 persons, 1 clock
# image 28/30: 375x500 16 persons, 2 handbags
# image 29/30: 375x500 19 persons, 1 motorcycle, 1 handbag
# image 30/30: 333x500 12 persons, 2 backpacks, 1 handbag, 1 clock
# Speed: 5.0ms pre-process, 122.5ms inference, 0.6ms NMS per image at shape (30, 3, 640, 640)

# %%
results.imgs[0]
# Out:
# array([[[ 94, 131, 175],
#         [ 93, 132, 175],
#         [ 95, 134, 177],
#         ...,
#         [ 93, 132, 173],
#         [ 91, 130, 171],
#         [ 90, 129, 170]],
#
#        [[ 92, 131, 174],
#         [ 93, 132, 175],
#         [ 94, 133, 176],
#         ...,
#         [ 92, 131, 172],
#         [ 90, 129, 170],
#         [ 89, 128, 169]],
#
#        [[ 92, 131, 174],
#         [ 92, 131, 174],
#         [ 93, 132, 175],
#         ...,
#         [ 91, 130, 171],
#         [ 89, 128, 169],
#         [ 88, 127, 168]],
#
#        ...,
#
#        [[ 77,  57,  59],
#         [ 93,  75,  73],
#         [102,  82,  83],
#         ...,
#         [ 21,  31,  56],
#         [ 32,  37,  56],
#         [ 43,  43,  55]],
#
#        [[ 92,  73,  75],
#         [ 97,  76,  73],
#         [ 82,  72,  71],
#         ...,
#         [ 43,  46,  55],
#         [ 60,  55,  59],
#         [ 70,  59,  57]],
#
#        [[103,  78,  73],
#         [ 80,  65,  68],
#         [ 77,  68,  71],
#         ...,
#         [ 71,  53,  49],
#         [ 72,  55,  47],
#         [ 68,  49,  42]]], dtype=uint8)

# %%
from PIL import Image

# %%
Image.fromarray(results.imgs[1])
# Out:
# <PIL.Image.Image image mode=RGB size=500x333>

# %%
results.save()
# Out:
# Saved 30 images to runs/detect/exp2
